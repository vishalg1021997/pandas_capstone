# %% [markdown]
# # Title: Problem for Covid - 19 Data Analysis Project using Python
#
# Dataset link :
# Url = https://raw.githubusercontent.com/SR1608/Datasets/main/coviddata.csv

# %% [markdown]
# # Perform following analysis on above dataset :

# %% [markdown]
# ### 1. Import the dataset using Pandas from above mentioned url.

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = "https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv"

df = pd.read_csv(url)
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# 2                     NaN           NaN         0.0                  NaN  ...
# 3                     NaN           NaN         0.0                  NaN  ...
# 4                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 57389                 NaN           7.0         NaN                  NaN  ...
# 57390                 NaN           7.0         NaN                  NaN  ...
# 57391                 NaN           7.0         NaN                  NaN  ...
# 57392                 NaN           7.0         NaN                  NaN  ...
# 57393                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 57389             NaN              NaN                    NaN
# 57390             NaN              NaN                    NaN
# 57391             NaN              NaN                    NaN
# 57392             NaN              NaN                    NaN
# 57393             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 57389                  NaN             NaN           NaN
# 57390                  NaN             NaN           NaN
# 57391                  NaN             NaN           NaN
# 57392                  NaN             NaN           NaN
# 57393                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 57389                     NaN                         NaN              NaN
# 57390                     NaN                         NaN              NaN
# 57391                     NaN                         NaN              NaN
# 57392                     NaN                         NaN              NaN
# 57393                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 57389                      NaN
# 57390                      NaN
# 57391                      NaN
# 57392                      NaN
# 57393                      NaN
#
# [57394 rows x 49 columns]

# %% [markdown]
# ### 2. High Level Data Understanding:
# ##### a. Find no. of rows & columns in the dataset

# %%
df.shape
# Out:
# (57394, 49)

# %%
df[df['location']=='United States']
# Out:
#       iso_code      continent       location      date  total_cases  \
# 53916      USA  North America  United States  31/12/19          NaN
# 53917      USA  North America  United States  01/01/20          NaN
# 53918      USA  North America  United States  02/01/20          NaN
# 53919      USA  North America  United States  03/01/20          NaN
# 53920      USA  North America  United States  04/01/20          NaN
# ...        ...            ...            ...       ...          ...
# 54234      USA  North America  United States  13/11/20   10554801.0
# 54235      USA  North America  United States  14/11/20   10739614.0
# 54236      USA  North America  United States  15/11/20   10904891.0
# 54237      USA  North America  United States  16/11/20   11037061.0
# 54238      USA  North America  United States  17/11/20   11205486.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 53916        0.0                 NaN           NaN         0.0
# 53917        0.0                 NaN           NaN         0.0
# 53918        0.0                 NaN           NaN         0.0
# 53919        0.0                 NaN           NaN         0.0
# 53920        0.0                 NaN           NaN         0.0
# ...          ...                 ...           ...         ...
# 54234   153669.0          135125.571      242430.0       630.0
# 54235   184813.0          142867.000      244345.0      1915.0
# 54236   165277.0          149133.286      245600.0      1255.0
# 54237   132170.0          152201.429      246214.0       614.0
# 54238   168425.0          156419.143      247220.0      1006.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 53916                  NaN  ...       54225.446              1.2
# 53917                  NaN  ...       54225.446              1.2
# 53918                  NaN  ...       54225.446              1.2
# 53919                  NaN  ...       54225.446              1.2
# 53920                  NaN  ...       54225.446              1.2
# ...                    ...  ...             ...              ...
# 54234             1070.429  ...       54225.446              1.2
# 54235             1178.000  ...       54225.446              1.2
# 54236             1212.429  ...       54225.446              1.2
# 54237             1234.571  ...       54225.446              1.2
# 54238             1281.286  ...       54225.446              1.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 53916                151.089                10.79            19.1
# 53917                151.089                10.79            19.1
# 53918                151.089                10.79            19.1
# 53919                151.089                10.79            19.1
# 53920                151.089                10.79            19.1
# ...                      ...                  ...             ...
# 54234                151.089                10.79            19.1
# 54235                151.089                10.79            19.1
# 54236                151.089                10.79            19.1
# 54237                151.089                10.79            19.1
# 54238                151.089                10.79            19.1
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 53916          24.6                     NaN                        2.77
# 53917          24.6                     NaN                        2.77
# 53918          24.6                     NaN                        2.77
# 53919          24.6                     NaN                        2.77
# 53920          24.6                     NaN                        2.77
# ...             ...                     ...                         ...
# 54234          24.6                     NaN                        2.77
# 54235          24.6                     NaN                        2.77
# 54236          24.6                     NaN                        2.77
# 54237          24.6                     NaN                        2.77
# 54238          24.6                     NaN                        2.77
#
#        life_expectancy  human_development_index
# 53916            78.86                    0.924
# 53917            78.86                    0.924
# 53918            78.86                    0.924
# 53919            78.86                    0.924
# 53920            78.86                    0.924
# ...                ...                      ...
# 54234            78.86                    0.924
# 54235            78.86                    0.924
# 54236            78.86                    0.924
# 54237            78.86                    0.924
# 54238            78.86                    0.924
#
# [323 rows x 49 columns]

# %% [markdown]
# ##### b. Data types of columns.

# %%
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# hosp_patients_per_million             float64
# weekly_icu_admissions                 float64
# weekly_icu_admissions_per_million     float64
# weekly_hosp_admissions                float64
# weekly_hosp_admissions_per_million    float64
# total_tests                           float64
# new_tests                             float64
# total_tests_per_thousand              float64
# new_tests_per_thousand                float64
# new_tests_smoothed                    float64
# new_tests_smoothed_per_thousand       float64
# tests_per_case                        float64
# positive_rate                         float64
# stringency_index                      float64
# population                            float64
# population_density                    float64
# median_age                            float64
# aged_65_older                         float64
# aged_70_older                         float64
# gdp_per_capita                        float64
# extreme_poverty                       float64
# cardiovasc_death_rate                 float64
# diabetes_prevalence                   float64
# female_smokers                        float64
# male_smokers                          float64
# handwashing_facilities                float64
# hospital_beds_per_thousand            float64
# life_expectancy                       float64
# human_development_index               float64
# dtype: object

# %% [markdown]
# ##### c. Info & describe of data in dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
#  11  new_cases_per_million               56401 non-null  float64
#  12  new_cases_smoothed_per_million      55587 non-null  float64
#  13  total_deaths_per_million            44096 non-null  float64
#  14  new_deaths_per_million              56401 non-null  float64
#  15  new_deaths_smoothed_per_million     55587 non-null  float64
#  16  reproduction_rate                   37696 non-null  float64
#  17  icu_patients                        4490 non-null   float64
#  18  icu_patients_per_million            4490 non-null   float64
#  19  hosp_patients                       5005 non-null   float64
#  20  hosp_patients_per_million           5005 non-null   float64
#  21  weekly_icu_admissions               357 non-null    float64
#  22  weekly_icu_admissions_per_million   357 non-null    float64
#  23  weekly_hosp_admissions              645 non-null    float64
#  24  weekly_hosp_admissions_per_million  645 non-null    float64
#  25  total_tests                         22017 non-null  float64
#  26  new_tests                           21787 non-null  float64
#  27  total_tests_per_thousand            22017 non-null  float64
#  28  new_tests_per_thousand              21787 non-null  float64
#  29  new_tests_smoothed                  24612 non-null  float64
#  30  new_tests_smoothed_per_thousand     24612 non-null  float64
#  31  tests_per_case                      22802 non-null  float64
#  32  positive_rate                       23211 non-null  float64
#  33  stringency_index                    47847 non-null  float64
#  34  population                          57071 non-null  float64
#  35  population_density                  54371 non-null  float64
#  36  median_age                          51034 non-null  float64
#  37  aged_65_older                       50265 non-null  float64
#  38  aged_70_older                       50768 non-null  float64
#  39  gdp_per_capita                      50367 non-null  float64
#  40  extreme_poverty                     33571 non-null  float64
#  41  cardiovasc_death_rate               51013 non-null  float64
#  42  diabetes_prevalence                 52881 non-null  float64
#  43  female_smokers                      39669 non-null  float64
#  44  male_smokers                        39156 non-null  float64
#  45  handwashing_facilities              24176 non-null  float64
#  46  hospital_beds_per_thousand          45936 non-null  float64
#  47  life_expectancy                     56336 non-null  float64
#  48  human_development_index             49247 non-null  float64
# dtypes: float64(45), object(4)
# memory usage: 21.5+ MB

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000                90.033000
# 50%        0.000000             0.286000               593.663000
# 75%        4.000000             4.000000              3487.050000
# max    10600.000000          9027.714000             76541.772000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           56401.000000                    55587.000000
# mean               39.344804                       38.403211
# std               133.985155                      101.649441
# min             -2212.545000                     -269.978000
# 25%                 0.000000                        0.260000
# 50%                 2.194000                        3.863000
# 75%                25.941000                       29.678500
# max              8652.658000                     2472.188000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              44096.000000  ...    50367.000000     33571.000000
# mean                  95.335293  ...    20620.172071        12.435453
# std                  180.721699  ...    20310.999832        19.427924
# min                    0.000000  ...      661.240000         0.100000
# 25%                    3.977750  ...     5321.444000         0.500000
# 50%                   20.383000  ...    13913.839000         2.000000
# 75%                   90.571250  ...    31400.840000        18.100000
# max                 1248.014000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           51013.000000         52881.000000    39669.000000
# mean              252.646642             8.070269       10.741569
# std               117.522344             4.189605       10.470743
# min                79.370000             0.990000        0.100000
# 25%               156.139000             5.310000        1.900000
# 50%               238.339000             7.110000        6.400000
# 75%               318.991000            10.390000       19.600000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  39156.000000            24176.000000                45936.000000
# mean      32.642686               52.089636                    3.089724
# std       13.453566               31.645306                    2.513193
# min        7.700000                1.188000                    0.100000
# 25%       21.400000               21.222000                    1.300000
# 50%       31.400000               52.232000                    2.500000
# 75%       40.900000               83.741000                    4.200000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     56336.000000             49247.000000
# mean         73.937780                 0.722223
# std           7.397016                 0.153261
# min          53.280000                 0.354000
# 25%          69.870000                 0.601000
# 50%          75.345000                 0.752000
# 75%          79.380000                 0.847000
# max          86.750000                 0.953000
#
# [8 rows x 45 columns]

# %% [markdown]
# ## 3. Low Level Data Understanding :
# ##### a. Find count of unique values in location column.

# %%
df['location'].unique().shape[0]
# Out:
# 216

# %% [markdown]
# ##### b. Find which continent has maximum frequency using values counts.

# %%
df['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %% [markdown]
# ##### c. Find maximum & mean value in 'total_cases'.

# %%
df['total_cases'].max()
# Out:
# 55154651.0

# %%
df['total_cases'].mean()
# Out:
# 167797.3688753302

# %% [markdown]
# ###### d. Find 25%,50% & 75% quartile value in 'total_deaths'.

# %%
df['total_deaths'].describe()
# Out:
# count    4.436800e+04
# mean     6.858639e+03
# std      5.578081e+04
# min      1.000000e+00
# 25%      1.300000e+01
# 50%      8.400000e+01
# 75%      7.270000e+02
# max      1.328537e+06
# Name: total_deaths, dtype: float64

# %%
df.total_deaths.quantile([0.25,0.5,0.75])
# Out:
# 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# ##### e. Find which continent has maximum 'human_development_index'.

# %%
df.groupby('continent').agg({'human_development_index':'max'}).idxmax()
# Out:
# human_development_index    Europe
# dtype: object

# %% [markdown]
# ##### f. Find which continent has minimum 'gdp_per_capita'.

# %%
df.groupby('continent').agg({'gdp_per_capita':'min'}).idxmin()
# Out:
# gdp_per_capita    Africa
# dtype: object

# %% [markdown]
# ## 4. Filter the dataframe with only this columns
# ['continent','location','date','total_cases','total_deaths','gdp_per_ca
# pita','
# human_development_index'] and update the data frame.

# %%
df = df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# 2            1803.987                    0.498
# 3            1803.987                    0.498
# 4            1803.987                    0.498
# ...               ...                      ...
# 57389             NaN                      NaN
# 57390             NaN                      NaN
# 57391             NaN                      NaN
# 57392             NaN                      NaN
# 57393             NaN                      NaN
#
# [57394 rows x 7 columns]

# %% [markdown]
# ## 5. Data Cleaning
# ##### a. Remove all duplicates observations

# %%
df.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# 2            1803.987                    0.498
# 3            1803.987                    0.498
# 4            1803.987                    0.498
# ...               ...                      ...
# 57389             NaN                      NaN
# 57390             NaN                      NaN
# 57391             NaN                      NaN
# 57392             NaN                      NaN
# 57393             NaN                      NaN
#
# [57394 rows x 7 columns]

# %% [markdown]
# ##### b. Find missing values in all columns

# %%
df.isnull()
# Out:
#        continent  location   date  total_cases  total_deaths  gdp_per_capita  \
# 0          False     False  False         True          True           False
# 1          False     False  False         True          True           False
# 2          False     False  False         True          True           False
# 3          False     False  False         True          True           False
# 4          False     False  False         True          True           False
# ...          ...       ...    ...          ...           ...             ...
# 57389       True     False  False        False         False            True
# 57390       True     False  False        False         False            True
# 57391       True     False  False        False         False            True
# 57392       True     False  False        False         False            True
# 57393       True     False  False        False         False            True
#
#        human_development_index
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 57389                     True
# 57390                     True
# 57391                     True
# 57392                     True
# 57393                     True
#
# [57394 rows x 7 columns]

# %% [markdown]
# ##### c. Remove all observations where continent column value is missing
#  Tip : using subset parameter in dropna

# %%
df.dropna(axis=0,subset=['continent'],inplace=True)
df
# Out:
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# 2            1803.987                    0.498
# 3            1803.987                    0.498
# 4            1803.987                    0.498
# ...               ...                      ...
# 56743        1899.775                    0.535
# 56744        1899.775                    0.535
# 56745        1899.775                    0.535
# 56746        1899.775                    0.535
# 56747        1899.775                    0.535
#
# [56748 rows x 7 columns]

# %% [markdown]
# ##### d. Fill all missing values with 0

# %%
df.fillna(0,inplace=True)
df
# Out:
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          0.0           0.0
# 1          Asia  Afghanistan  01/01/20          0.0           0.0
# 2          Asia  Afghanistan  02/01/20          0.0           0.0
# 3          Asia  Afghanistan  03/01/20          0.0           0.0
# 4          Asia  Afghanistan  04/01/20          0.0           0.0
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# 2            1803.987                    0.498
# 3            1803.987                    0.498
# 4            1803.987                    0.498
# ...               ...                      ...
# 56743        1899.775                    0.535
# 56744        1899.775                    0.535
# 56745        1899.775                    0.535
# 56746        1899.775                    0.535
# 56747        1899.775                    0.535
#
# [56748 rows x 7 columns]

# %% [markdown]
# ## 6. Date time format :
# ##### a. Convert date column in datetime format using pandas.to_datetime

# %%
df['date'] = pd.to_datetime(df['date'])
print(df.dtypes)
df
# Out:
# continent                          object
# location                           object
# date                       datetime64[ns]
# total_cases                       float64
# total_deaths                      float64
# gdp_per_capita                    float64
# human_development_index           float64
# dtype: object
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# 2            1803.987                    0.498
# 3            1803.987                    0.498
# 4            1803.987                    0.498
# ...               ...                      ...
# 56743        1899.775                    0.535
# 56744        1899.775                    0.535
# 56745        1899.775                    0.535
# 56746        1899.775                    0.535
# 56747        1899.775                    0.535
#
# [56748 rows x 7 columns]

# %% [markdown]
# ##### b. Create new column month after extracting month data from date column.

# %%
df['month'] = df['date'].dt.month
df
# Out:
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# 1            1803.987                    0.498      1
# 2            1803.987                    0.498      2
# 3            1803.987                    0.498      3
# 4            1803.987                    0.498      4
# ...               ...                      ...    ...
# 56743        1899.775                    0.535     11
# 56744        1899.775                    0.535     11
# 56745        1899.775                    0.535     11
# 56746        1899.775                    0.535     11
# 56747        1899.775                    0.535     11
#
# [56748 rows x 8 columns]

# %% [markdown]
# ## 7. Data Aggregation:
# ##### a. Find max value in all columns using groupby function on 'continent' column
#  Tip: use reset_index() after applying groupby

# %%
df.groupby('continent').max()
# Out:
#                                    location       date  total_cases  \
# continent
# Africa                             Zimbabwe 2020-12-11     752269.0
# Asia                                  Yemen 2020-12-11    8874290.0
# Europe                              Vatican 2020-12-11    1991233.0
# North America  United States Virgin Islands 2020-12-11   11205486.0
# Oceania                   Wallis and Futuna 2020-12-11      27750.0
# South America                     Venezuela 2020-12-11    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index  month
# continent
# Africa              20314.0       26382.287                    0.797     12
# Asia               130519.0      116935.600                    0.933     12
# Europe              52147.0       94277.965                    0.953     12
# North America      247220.0       54225.446                    0.926     12
# Oceania               907.0       44648.710                    0.939     12
# South America      166014.0       22767.037                    0.843     12

# %%
df.reset_index()
# Out:
#        index continent     location       date  total_cases  total_deaths  \
# 0          0      Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          1      Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          2      Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          3      Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          4      Asia  Afghanistan 2020-04-01          0.0           0.0
# ...      ...       ...          ...        ...          ...           ...
# 56743  56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744  56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745  56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746  56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747  56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# 1            1803.987                    0.498      1
# 2            1803.987                    0.498      2
# 3            1803.987                    0.498      3
# 4            1803.987                    0.498      4
# ...               ...                      ...    ...
# 56743        1899.775                    0.535     11
# 56744        1899.775                    0.535     11
# 56745        1899.775                    0.535     11
# 56746        1899.775                    0.535     11
# 56747        1899.775                    0.535     11
#
# [56748 rows x 9 columns]

# %% [markdown]
# ##### b. Store the result in a new dataframe named 'df_groupby'.
#  (Use df_groupby dataframe for all further analysis)

# %%
df_groupby = df
df_groupby
# Out:
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# 1            1803.987                    0.498      1
# 2            1803.987                    0.498      2
# 3            1803.987                    0.498      3
# 4            1803.987                    0.498      4
# ...               ...                      ...    ...
# 56743        1899.775                    0.535     11
# 56744        1899.775                    0.535     11
# 56745        1899.775                    0.535     11
# 56746        1899.775                    0.535     11
# 56747        1899.775                    0.535     11
#
# [56748 rows x 8 columns]

# %% [markdown]
# ## 8. Feature Engineering :
# ##### a. Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
df_groupby['total_deaths_to_total_cases'] = df_groupby['total_deaths']/df_groupby['total_cases']
df_groupby
# Out:
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#       continent     location       date  total_cases  total_deaths  \
# 0          Asia  Afghanistan 2019-12-31          0.0           0.0
# 1          Asia  Afghanistan 2020-01-01          0.0           0.0
# 2          Asia  Afghanistan 2020-02-01          0.0           0.0
# 3          Asia  Afghanistan 2020-03-01          0.0           0.0
# 4          Asia  Afghanistan 2020-04-01          0.0           0.0
# ...         ...          ...        ...          ...           ...
# 56743    Africa     Zimbabwe 2020-11-13       8696.0         255.0
# 56744    Africa     Zimbabwe 2020-11-14       8765.0         257.0
# 56745    Africa     Zimbabwe 2020-11-15       8786.0         257.0
# 56746    Africa     Zimbabwe 2020-11-16       8786.0         257.0
# 56747    Africa     Zimbabwe 2020-11-17       8897.0         257.0
#
#        gdp_per_capita  human_development_index  month  \
# 0            1803.987                    0.498     12
# 1            1803.987                    0.498      1
# 2            1803.987                    0.498      2
# 3            1803.987                    0.498      3
# 4            1803.987                    0.498      4
# ...               ...                      ...    ...
# 56743        1899.775                    0.535     11
# 56744        1899.775                    0.535     11
# 56745        1899.775                    0.535     11
# 56746        1899.775                    0.535     11
# 56747        1899.775                    0.535     11
#
#        total_deaths_to_total_cases
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 56743                     0.029324
# 56744                     0.029321
# 56745                     0.029251
# 56746                     0.029251
# 56747                     0.028886
#
# [56748 rows x 9 columns]

# %% [markdown]
# ## 9. Data Visualization :
# ##### a. Perform Univariate analysis on 'gdp_per_capita' column by plotting
# ##### histogram using seaborn dist plot.

# %%
sns.distplot(df_groupby['gdp_per_capita'])
# Out:
# C:\Users\Vishal Gupta\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %% [markdown]
# #####  b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
sns.scatterplot(data=df_groupby,x='total_cases',y='gdp_per_capita')
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='gdp_per_capita'>

# %% [markdown]
# ##### c. Plot Pairplot on df_groupby dataset.

# %%
sns.pairplot(data=df_groupby)

# %% [markdown]
# ##### d. Plot a bar plot of 'continent' column with 'total_cases' .
#  Tip : using kind='bar' in seaborn catplot

# %%
sns.catplot(data=df_groupby,x='continent',y='total_cases',kind = 'bar')

# %% [markdown]
# ## 10.Save the df_groupby dataframe in your local drive using pandas.to_csv function .

# %%
df.to_csv('df_groupby.csv')
